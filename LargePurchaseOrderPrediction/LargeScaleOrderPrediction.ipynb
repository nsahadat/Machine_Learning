# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from torch.utils.tensorboard import SummaryWriter
import pickle

# %%
writer = SummaryWriter()

# %%
# !pip install --user numpy==1.19.2

# %%
# !pip install jupyter_contrib_nbextensions

# %%
data = pd.read_csv('./Data/PURCHASE ORDER DATA EXTRACT 2012-2015_0.csv')

# %%
data.shape
# Out:
# (346018, 31)

# %% [markdown]
# ## Checking the data types

# %%
for c in data.columns:
    print(f'{c}:{data[c].dtypes}')
# Out:
# Creation Date:object
# Purchase Date:object
# Fiscal Year:object
# LPA Number:object
# Purchase Order Number:object
# Requisition Number:object
# Acquisition Type:object
# Sub-Acquisition Type:object
# Acquisition Method:object
# Sub-Acquisition Method:object
# Department Name:object
# Supplier Code:float64
# Supplier Name:object
# Supplier Qualifications:object
# Supplier Zip Code:object
# CalCard:object
# Item Name:object
# Item Description:object
# Quantity:float64
# Unit Price:object
# Total Price:object
# Classification Codes:object
# Normalized UNSPSC:float64
# Commodity Title:object
# Class:float64
# Class Title:object
# Family:float64
# Family Title:object
# Segment:float64
# Segment Title:object
# Location:object

# %%
# for c in data.columns:
#     print(f'{c}:{data[c].value_counts()}')

# %%
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
# data['Total Price'].fillna('-1', inplace = True)

# %%
# for p in data['Total Price'].to_list():
#     # print(p)
#     if ('$' not in p):
#         print(p)

# %%
data['Purchase Date'] = pd.to_datetime(data['Purchase Date'], errors='coerce')

# %%
data['Creation Date'] = pd.to_datetime(data['Creation Date'], errors='coerce')

# %%
data['Total Price'] = data['Total Price'].str.replace('$','', regex=True).astype(float)

# %%
data['Unit Price'] = data['Unit Price'].str.replace('$','', regex=True).astype(float)

# %% [markdown]
# ## Split Data into train test

# %%
train_data, test_data = train_test_split(data,test_size=0.01)

print([train_data.shape, test_data.shape])
# Out:
# [(342557, 31), (3461, 31)]

# %% [markdown]
# ## Initialize Transformer

# %%
from rdt import HyperTransformer

ht = HyperTransformer()

ht.detect_initial_config(data=train_data)

print(ht.get_config())
# Out:
# {
#     "sdtypes": {
#         "Creation Date": "datetime",
#         "Purchase Date": "datetime",
#         "Fiscal Year": "categorical",
#         "LPA Number": "categorical",
#         "Purchase Order Number": "categorical",
#         "Requisition Number": "categorical",
#         "Acquisition Type": "categorical",
#         "Sub-Acquisition Type": "categorical",
#         "Acquisition Method": "categorical",
#         "Sub-Acquisition Method": "categorical",
#         "Department Name": "categorical",
#         "Supplier Code": "numerical",
#         "Supplier Name": "categorical",
#         "Supplier Qualifications": "categorical",
#         "Supplier Zip Code": "categorical",
#         "CalCard": "categorical",
#         "Item Name": "categorical",
#         "Item Description": "categorical",
#         "Quantity": "numerical",
#         "Unit Price": "numerical",
#         "Total Price": "numerical",
#         "Classification Codes": "categorical",
#         "Normalized UNSPSC": "numerical",
#         "Commodity Title": "categorical",
#         "Class": "numerical",
#         "Class Title": "categorical",
#         "Family": "numerical",
#         "Family Title": "categorical",
#         "Segment": "numerical",
#         "Segment Title": "categorical",
#         "Location": "categorical"
#     },
#     "transformers": {
#         "Creation Date": UnixTimestampEncoder(),
#         "Purchase Date": UnixTimestampEncoder(),
#         "Fiscal Year": UniformEncoder(),
#         "LPA Number": UniformEncoder(),
#         "Purchase Order Number": UniformEncoder(),
#         "Requisition Number": UniformEncoder(),
#         "Acquisition Type": UniformEncoder(),
#         "Sub-Acquisition Type": UniformEncoder(),
#         "Acquisition Method": UniformEncoder(),
#         "Sub-Acquisition Method": UniformEncoder(),
#         "Department Name": UniformEncoder(),
#         "Supplier Code": FloatFormatter(),
#         "Supplier Name": UniformEncoder(),
#         "Supplier Qualifications": UniformEncoder(),
#         "Supplier Zip Code": UniformEncoder(),
#         "CalCard": UniformEncoder(),
#         "Item Name": UniformEncoder(),
#         "Item Description": UniformEncoder(),
#         "Quantity": FloatFormatter(),
#         "Unit Price": FloatFormatter(),
#         "Total Price": FloatFormatter(),
#         "Classification Codes": UniformEncoder(),
#         "Normalized UNSPSC": FloatFormatter(),
#         "Commodity Title": UniformEncoder(),
#         "Class": FloatFormatter(),
#         "Class Title": UniformEncoder(),
#         "Family": FloatFormatter(),
#         "Family Title": UniformEncoder(),
#         "Segment": FloatFormatter(),
#         "Segment Title": UniformEncoder(),
#         "Location": UniformEncoder()
#     }
# }

# %%
from rdt.transformers import *

ht.set_config(config={
  'sdtypes': {
    'Creation Date': 'datetime',
    'Purchase Date': 'datetime'
  },
  'transformers': {
#     'Creation Date': UnixTimestampEncoder(missing_value_replacement="mean"),
#     'Purchase Date': UnixTimestampEncoder(missing_value_replacement="mean")
      'Creation Date': OptimizedTimestampEncoder(missing_value_replacement='mean'),
      'Purchase Date': OptimizedTimestampEncoder(missing_value_replacement='mean')
  }
})

ht.update_transformers_by_sdtype(sdtype='numerical',
  transformer_name='ClusterBasedNormalizer',
  transformer_parameters={'missing_value_generation': 'from_column',
                          'weight_threshold': 0.01,
                         'enforce_min_max_values': True})

ht.get_config()
# Out:
# {
#     "sdtypes": {
#         "Creation Date": "datetime",
#         "Purchase Date": "datetime",
#         "Fiscal Year": "categorical",
#         "LPA Number": "categorical",
#         "Purchase Order Number": "categorical",
#         "Requisition Number": "categorical",
#         "Acquisition Type": "categorical",
#         "Sub-Acquisition Type": "categorical",
#         "Acquisition Method": "categorical",
#         "Sub-Acquisition Method": "categorical",
#         "Department Name": "categorical",
#         "Supplier Code": "numerical",
#         "Supplier Name": "categorical",
#         "Supplier Qualifications": "categorical",
#         "Supplier Zip Code": "categorical",
#         "CalCard": "categorical",
#         "Item Name": "categorical",
#         "Item Description": "categorical",
#         "Quantity": "numerical",
#         "Unit Price": "numerical",
#         "Total Price": "numerical",
#         "Classification Codes": "categorical",
#         "Normalized UNSPSC": "numerical",
#         "Commodity Title": "categorical",
#         "Class": "numerical",
#         "Class Title": "categorical",
#         "Family": "numerical",
#         "Family Title": "categorical",
#         "Segment": "numerical",
#         "Segment Title": "categorical",
#         "Location": "categorical"
#     },
#     "transformers": {
#         "Creation Date": OptimizedTimestampEncoder(missing_value_replacement='mean'),
#         "Purchase Date": OptimizedTimestampEncoder(missing_value_replacement='mean'),
#         "Fiscal Year": UniformEncoder(),
#         "LPA Number": UniformEncoder(),
#         "Purchase Order Number": UniformEncoder(),
#         "Requisition Number": UniformEncoder(),
#         "Acquisition Type": UniformEncoder(),
#         "Sub-Acquisition Type": UniformEncoder(),
#         "Acquisition Method": UniformEncoder(),
#         "Sub-Acquisition Method": UniformEncoder(),
#         "Department Name": UniformEncoder(),
#         "Supplier Code": ClusterBasedNormalizer(enforce_min_max_values=True, weight_threshold=0.01, missing_value_generation='from_column'),
#         "Supplier Name": UniformEncoder(),
#         "Supplier Qualifications": UniformEncoder(),
#         "Supplier Zip Code": UniformEncoder(),
#         "CalCard": UniformEncoder(),
#         "Item Name": UniformEncoder(),
#         "Item Description": UniformEncoder(),
#         "Quantity": ClusterBasedNormalizer(enforce_min_max_values=True, weight_threshold=0.01, missing_value_generation='from_column'),
#         "Unit Price": ClusterBasedNormalizer(enforce_min_max_values=True, weight_threshold=0.01, missing_value_generation='from_column'),
#         "Total Price": ClusterBasedNormalizer(enforce_min_max_values=True, weight_threshold=0.01, missing_value_generation='from_column'),
#         "Classification Codes": UniformEncoder(),
#         "Normalized UNSPSC": ClusterBasedNormalizer(enforce_min_max_values=True, weight_threshold=0.01, missing_value_generation='from_column'),
#         "Commodity Title": UniformEncoder(),
#         "Class": ClusterBasedNormalizer(enforce_min_max_values=True, weight_threshold=0.01, missing_value_generation='from_column'),
#         "Class Title": UniformEncoder(),
#         "Family": ClusterBasedNormalizer(enforce_min_max_values=True, weight_threshold=0.01, missing_value_generation='from_column'),
#         "Family Title": UniformEncoder(),
#         "Segment": ClusterBasedNormalizer(enforce_min_max_values=True, weight_threshold=0.01, missing_value_generation='from_column'),
#         "Segment Title": UniformEncoder(),
#         "Location": UniformEncoder()
#     }
# }

# %%
# copy the original data
# train_data_masked = train_data.copy()
# mask it
# train_data_masked[train_data_mask_ind] = np.nan

# fit the transformer
# train_data_ = ht.fit_transform(train_data)

# Mask 10% of the data
# train_data_mask_ind = np.random.rand(*train_data_.shape)< 0.1

# transform the data
# train_data_ = ht.transform(train_data)
# train_data_masked_ = ht.transform(train_data_masked)

# %%
# pickle.dump(ht, open('transformer.p', 'wb'))
# pickle.dump(train_data_, open('train_data_.p', 'wb'))

# %%
ht = pickle.load(open('transformer.p', 'rb'))
train_data_ = pickle.load(open('train_data_.p', 'rb'))

train_data_mask_ind = np.random.rand(*train_data_.shape)< 0.1

# %%
# train_data_

# %% [markdown]
# ## Algorithm to generate data from Embedding

# %%
from torch.utils.data import Dataset

class MyDataset(Dataset):
    def __init__(self, data, target):
        self.data = torch.tensor(data.values).float()
        self.target = torch.tensor(target)#.float()
        
    def __getitem__(self, idx):
        return self.data[idx,:], self.target[idx,:]
    
    def __len__(self):
        return len(self.data)

# %%
from torch.utils.data import DataLoader
from torch.autograd import Variable
from torch.utils.data import Dataset
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import time
import pickle
import os


class AE(nn.Module):
    def __init__(self, **kwargs):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Linear(in_features=kwargs["input_shape"], out_features=128),
            nn.ReLU(),
            nn.Linear(in_features=128, out_features=64),
            nn.ReLU(),
            nn.Linear(in_features=64, out_features=32),
            nn.ReLU(),
            nn.Linear(in_features=32, out_features=kwargs['hidden'])
        )
        self.decoder = nn.Sequential(
            nn.Linear(in_features=kwargs['hidden'], out_features=32),
            nn.ReLU(),
            nn.Linear(in_features=32, out_features=64),
            nn.ReLU(),
            nn.Linear(in_features=64, out_features=128),
            nn.ReLU(),
            nn.Linear(in_features=128, out_features=kwargs["input_shape"])
        )

    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded
    
def train_autoencoder(model, test_data, optimizer_autoencoder, criterion_mse, criterion_ce, device, batch_size=512, epochs = 500):
    train_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size, shuffle=True)

    losses = []
    for epoch in range(epochs):
        loss = 0
        for inputs, ind_masked in train_loader:
            # inputs has all the value that is expected to predict
            # target is the masked index
            
            # reshaped data
            targets = inputs.detach().clone().to(device)
#             ind_masked = ind_masked.view(-1, ind_masked.shape[1]).to(device)
            
            inputs[ind_masked==1] = -1 #float('nan')
            
            # reset the gradients back to zero
            # PyTorch accumulates gradients on subsequent backward passes
            optimizer_autoencoder.zero_grad()

            # compute reconstructions
            outputs = model(inputs.to(device))

            # compute training reconstruction loss
            train_loss = criterion_mse(outputs[ind_masked==1], targets[ind_masked==1])**2 + criterion_mse(outputs, targets)
            #+ criterion_ce(outputs[ind_masked==1], labels)
            
#             print(f'inputs shape: {inputs.shape}\noutputs shape: {outputs.shape}\ntargets shape: {targets.shape}')
#             print(criterion_ce(outputs[ind_masked==1].view(labels.shape[0], labels.shape[1]), labels.softmax(dim=1)))
#             print([outputs[ind_masked==1].shape[0], labels.shape[0]])
    
            # compute accumulated gradients
            train_loss.backward()

            # perform parameter update based on current gradients
            optimizer_autoencoder.step()

            # add the mini-batch training loss to epoch loss
            loss += train_loss.item()
            

        # compute the epoch training loss
        losses.append([epoch, loss])
        
        writer.add_scalar('Loss/train', loss, epoch)
        # display the epoch training loss
        print("epoch : {}/{}, loss = {:.3f}".format(epoch + 1, epochs, loss))

# %%
train_dataset = MyDataset(train_data_, train_data_mask_ind)

# %%
st = time.time()

# Initialize autoencoder
model = AE(input_shape=train_data_.shape[1], hidden = 10).to(device)

# show model in tensorboard
train_iter = iter(train_dataset)
train_d, train_l = next(train_iter)

writer.add_graph(model, train_d.to(device))
writer.close()

# create an optimizer object
# Adam optimizer with learning rate 1e-3
optimizer_autoencoder = optim.Adam(model.parameters(), lr=1e-3)

# criteria for autoencoder
criterion_mse = nn.MSELoss()
criterion_ce = nn.CrossEntropyLoss(reduction='mean')


# train autoencoder
train_autoencoder(model, train_dataset, optimizer_autoencoder, criterion_mse, criterion_ce, device, batch_size=256, epochs=100)

et = time.time()

print(f'Total Execution time: {et-st}s')

pickle.dump(model, open(f'{os.getcwd()}/autoencoder.p', 'wb'))
# Out:
# epoch : 1/100, loss = 4907482575264835.000
# epoch : 2/100, loss = 819358873567668.000
# epoch : 3/100, loss = 79703044676718.000
# epoch : 4/100, loss = 61459071413314.062
# epoch : 5/100, loss = 45696122925750.500
# epoch : 6/100, loss = 44498639525817.500
# epoch : 7/100, loss = 42346570523085.750
# epoch : 8/100, loss = 34931538058851.500
# epoch : 9/100, loss = 30364459920546.500
# epoch : 10/100, loss = 36721981913552.000
# epoch : 11/100, loss = 29626241636031.000
# epoch : 12/100, loss = 29599957303688.750
# epoch : 13/100, loss = 26864256790087.500
# epoch : 14/100, loss = 25085997677108.500
# epoch : 15/100, loss = 25403576566378.500
# epoch : 16/100, loss = 29315502278888.500
# epoch : 17/100, loss = 26926931623547.500
# epoch : 18/100, loss = 27770546491063.812
# epoch : 19/100, loss = 21709379922146.250
# epoch : 20/100, loss = 25386929290558.016
# epoch : 21/100, loss = 29173642651772.516
# epoch : 22/100, loss = 23934399966366.969
# epoch : 23/100, loss = 22247602614846.609
# epoch : 24/100, loss = 24636669427599.750
# epoch : 25/100, loss = 24589674339581.781
# epoch : 26/100, loss = 23965173455682.375
# epoch : 27/100, loss = 27194718092219.828
# epoch : 28/100, loss = 26922358661510.703
# epoch : 29/100, loss = 24074064978935.250
# epoch : 30/100, loss = 24887543130832.094
# epoch : 31/100, loss = 22065174619294.781
# epoch : 32/100, loss = 25700986836747.719
# epoch : 33/100, loss = 23655994569622.461
# epoch : 34/100, loss = 23252501344802.414
# epoch : 35/100, loss = 23436772185701.336
# epoch : 36/100, loss = 25086626969767.906
# epoch : 37/100, loss = 23244351213113.812
# epoch : 38/100, loss = 23351200052280.133
# epoch : 39/100, loss = 23909732152214.953
# epoch : 40/100, loss = 29063181552541.938
# epoch : 41/100, loss = 22219246805019.820
# epoch : 42/100, loss = 58517074032166.125
# epoch : 43/100, loss = 24106095497537.438
# epoch : 44/100, loss = 22105627177266.000
# epoch : 45/100, loss = 26262263377305.812
# epoch : 46/100, loss = 23008996427314.719
# epoch : 47/100, loss = 23340948814847.203
# epoch : 48/100, loss = 23426464802212.328
# epoch : 49/100, loss = 23870422277074.293
# epoch : 50/100, loss = 25120510343958.422
# epoch : 51/100, loss = 22691268383511.938
# epoch : 52/100, loss = 26281331861813.742
# epoch : 53/100, loss = 22256753959971.188
# epoch : 54/100, loss = 23304434677793.406
# epoch : 55/100, loss = 22526564619002.047
# epoch : 56/100, loss = 23824608947202.406
# epoch : 57/100, loss = 23342658521956.656
# epoch : 58/100, loss = 22863900697366.359
# epoch : 59/100, loss = 22333958381682.812
# epoch : 60/100, loss = 22855460543244.953
# epoch : 61/100, loss = 24180270043460.777
# epoch : 62/100, loss = 24745781569472.672
# epoch : 63/100, loss = 21560089778440.281
# epoch : 64/100, loss = 23523424854434.875
# epoch : 65/100, loss = 21136575901129.375
# epoch : 66/100, loss = 21621693133348.555
# epoch : 67/100, loss = 22650977633321.617
# epoch : 68/100, loss = 22546967333902.688
# epoch : 69/100, loss = 25629462949152.875
# epoch : 70/100, loss = 21360652552139.824
# epoch : 71/100, loss = 25087196442393.656
# epoch : 72/100, loss = 22396743533956.750
# epoch : 73/100, loss = 23483786571605.969
# epoch : 74/100, loss = 22766276662268.633
# epoch : 75/100, loss = 22431952584953.438
# epoch : 76/100, loss = 23364334235829.969
# epoch : 77/100, loss = 23243637404980.773
# epoch : 78/100, loss = 23113584406734.766
# epoch : 79/100, loss = 22809792356819.062
# epoch : 80/100, loss = 22721162879091.391
# epoch : 81/100, loss = 23590685503861.922
# epoch : 82/100, loss = 21280285119135.734
# epoch : 83/100, loss = 24582667139345.945
# epoch : 84/100, loss = 21696748104902.094
# epoch : 85/100, loss = 22764414552887.828
# epoch : 86/100, loss = 21901994528578.750
# epoch : 87/100, loss = 21984948756412.547
# epoch : 88/100, loss = 21791750410028.484
# epoch : 89/100, loss = 21914073232569.812
# epoch : 90/100, loss = 30217127295044.453
# epoch : 91/100, loss = 23765345906800.000
# epoch : 92/100, loss = 23179547539969.344
# epoch : 93/100, loss = 20966279555877.281
# epoch : 94/100, loss = 21804286877312.148
# epoch : 95/100, loss = 22452203872149.438
# epoch : 96/100, loss = 22734299404039.688
# epoch : 97/100, loss = 23060805952587.844
# epoch : 98/100, loss = 21123295134152.188
# epoch : 99/100, loss = 21126084647070.312
# epoch : 100/100, loss = 22237626996789.844
# Total Execution time: 1163.675564289093s

# %% [markdown]
# ## Test Data

# %%
ind_mask_test = np.random.rand(*test_data.shape) < 0.1

# %%
(ind_mask_test==True).sum()/(test_data.shape[0]*test_data.shape[1])
# Out:
# 0.09987790215395513

# %%
test_data_masked = test_data.copy()
test_data_masked[ind_mask_test] = np.nan

# %%
pd.options.display.max_columns = 100

# %%
test_data_masked.head(1)
# Out:
#        Creation Date Purchase Date Fiscal Year LPA Number  \
# 111013    2014-06-18    2014-05-16   2013-2014        NaN
#
#        Purchase Order Number Requisition Number Acquisition Type  \
# 111013               13-5314                NaN  NON-IT Services
#
#                                Sub-Acquisition Type Acquisition Method  \
# 111013  Services are specifically exempt by statute                NaN
#
#        Sub-Acquisition Method  \
# 111013                    NaN
#
#                                           Department Name  Supplier Code  \
# 111013  Statewide Health Planning & Development, Offic...      1786916.0
#
#        Supplier Name Supplier Qualifications Supplier Zip Code CalCard  \
# 111013  Paul Mueller                     NaN               NaN      NO
#
#        Item Name  Item Description  Quantity  Unit Price  Total Price  \
# 111013  Contract  Medical Training       1.0      7792.0       7792.0
#
#        Classification Codes  Normalized UNSPSC  \
# 111013             86101605         86101605.0
#
#                              Commodity Title       Class  \
# 111013  Medical vocational training services  86101600.0
#
#                                     Class Title      Family  \
# 111013  Scientific vocational training services  86100000.0
#
#                Family Title     Segment                    Segment Title  \
# 111013  Vocational training  86000000.0  Education and Training Services
#
#        Location
# 111013      NaN

# %%
with torch.no_grad():
    test_transformed = ht.transform(test_data_masked)
    out = pd.DataFrame(model(torch.tensor(test_transformed.values.astype('float32')).to(device)).to('cpu').numpy(), columns=test_transformed.columns)
    out_predicted = ht.reverse_transform(out)
# Out:
# C:\Users\mnsah\AppData\Roaming\Python\Python38\site-packages\rdt\transformers\categorical.py:153: UserWarning: The data in column 'Fiscal Year' contains new categories that did not appear during 'fit' (nan). Assigning them random values. If you want to model new categories, please fit the data again using 'fit'.
#   warnings.warn(
# C:\Users\mnsah\AppData\Roaming\Python\Python38\site-packages\rdt\transformers\categorical.py:153: UserWarning: The data in column 'Purchase Order Number' contains new categories that did not appear during 'fit' (nan, PO 221300000612, 76WD2002, +12 more). Assigning them random values. If you want to model new categories, please fit the data again using 'fit'.
#   warnings.warn(
# C:\Users\mnsah\AppData\Roaming\Python\Python38\site-packages\rdt\transformers\categorical.py:153: UserWarning: The data in column 'Acquisition Type' contains new categories that did not appear during 'fit' (nan). Assigning them random values. If you want to model new categories, please fit the data again using 'fit'.
#   warnings.warn(
# C:\Users\mnsah\AppData\Roaming\Python\Python38\site-packages\rdt\transformers\categorical.py:153: UserWarning: The data in column 'Acquisition Method' contains new categories that did not appear during 'fit' (nan). Assigning them random values. If you want to model new categories, please fit the data again using 'fit'.
#   warnings.warn(
# C:\Users\mnsah\AppData\Roaming\Python\Python38\site-packages\rdt\transformers\categorical.py:153: UserWarning: The data in column 'Department Name' contains new categories that did not appear during 'fit' (nan). Assigning them random values. If you want to model new categories, please fit the data again using 'fit'.
#   warnings.warn(
# C:\Users\mnsah\AppData\Roaming\Python\Python38\site-packages\rdt\transformers\categorical.py:153: UserWarning: The data in column 'Supplier Name' contains new categories that did not appear during 'fit' (INTERNATIONAL GLOBAL ENTERPRISES, INC.). Assigning them random values. If you want to model new categories, please fit the data again using 'fit'.
#   warnings.warn(
# C:\Users\mnsah\AppData\Roaming\Python\Python38\site-packages\rdt\transformers\categorical.py:153: UserWarning: The data in column 'CalCard' contains new categories that did not appear during 'fit' (nan). Assigning them random values. If you want to model new categories, please fit the data again using 'fit'.
#   warnings.warn(
# C:\Users\mnsah\AppData\Roaming\Python\Python38\site-packages\rdt\transformers\categorical.py:153: UserWarning: The data in column 'Item Name' contains new categories that did not appear during 'fit' (Mathcad Professional Floating License-Annual Maintenance, LESS LETHAL BATONS, Raco 4x 4 Duplex Receptacle Square Box Cover, +9 more). Assigning them random values. If you want to model new categories, please fit the data again using 'fit'.
#   warnings.warn(
# C:\Users\mnsah\AppData\Roaming\Python\Python38\site-packages\rdt\transformers\categorical.py:153: UserWarning: The data in column 'Item Description' contains new categories that did not appear during 'fit' (Mathcad Professional Floating License-Annual Maintenance, LESS LETHAL BATONS, Raco 4x 4 Duplex Receptacle Square Box Cover, +16 more). Assigning them random values. If you want to model new categories, please fit the data again using 'fit'.
#   warnings.warn(
# C:\Users\mnsah\AppData\Roaming\Python\Python38\site-packages\rdt\transformers\categorical.py:153: UserWarning: The data in column 'Classification Codes' contains new categories that did not appear during 'fit' (26111706
# 42211812
# 42281904). Assigning them random values. If you want to model new categories, please fit the data again using 'fit'.
#   warnings.warn(

# %%
# from sklearn.metrics import mean_squared_error

# overall_loss = 0
# for i,ind in enumerate(ind_mask_test):
#     if ind.sum()>0:
#         loss = mean_squared_error(test_data_.iloc[i,ind].values, out.iloc[i,ind].values)
#         print(f'{i}: {loss}')
#         overall_loss += loss

# print(f'Overall mse loss: {overall_loss}')

# %%
test_data.head(3)
# Out:
#        Creation Date Purchase Date Fiscal Year LPA Number  \
# 111013    2014-06-18    2014-05-16   2013-2014        NaN
# 265353    2015-05-01    2015-04-09   2014-2015        NaN
# 118804    2014-05-14    2014-05-14   2013-2014        NaN
#
#        Purchase Order Number Requisition Number Acquisition Type  \
# 111013               13-5314                NaN  NON-IT Services
# 265353         NMED532237137                NaN  NON-IT Services
# 118804                 X2253                NaN     NON-IT Goods
#
#                                Sub-Acquisition Type  \
# 111013  Services are specifically exempt by statute
# 265353  Services are specifically exempt by statute
# 118804                                          NaN
#
#                                  Acquisition Method Sub-Acquisition Method  \
# 111013  Services are specifically exempt by statute                    NaN
# 265353  Services are specifically exempt by statute                    NaN
# 118804                         Informal Competitive                    NaN
#
#                                           Department Name  Supplier Code  \
# 111013  Statewide Health Planning & Development, Offic...      1786916.0
# 265353                      Rehabilitation, Department of      1708000.0
# 118804                             Justice, Department of      1745786.0
#
#                                    Supplier Name Supplier Qualifications  \
# 111013                              Paul Mueller                     NaN
# 265353  Mount St. Mary's College - Doheny Campus                     NaN
# 118804                        Neogen Corporation                     NaN
#
#        Supplier Zip Code CalCard                 Item Name  \
# 111013               NaN      NO                  Contract
# 265353             90007      NO  vocational rehabiliation
# 118804               NaN      NO                lab supply
#
#                                          Item Description  Quantity  \
# 111013                                   Medical Training       1.0
# 265353                                   Summer 2015 fees       1.0
# 118804  methamphetamine Group (RTU) Forensic kit 480 well      18.0
#
#         Unit Price  Total Price Classification Codes  Normalized UNSPSC  \
# 111013      7792.0       7792.0             86101605         86101605.0
# 265353     10935.0      10935.0             86101803         86101803.0
# 118804       335.0       6030.0   41106103\n51151729         41106103.0
#
#                               Commodity Title       Class  \
# 111013   Medical vocational training services  86101600.0
# 265353     Vocational rehabilitation services  86101800.0
# 118804  Deoxyribonucleic acid DNA typing kits  41106100.0
#
#                                          Class Title      Family  \
# 111013       Scientific vocational training services  86100000.0
# 265353  In service training and manpower development  86100000.0
# 118804       Deoxyribonucleic acid DNA analysis kits  41100000.0
#
#                                Family Title     Segment  \
# 111013                  Vocational training  86000000.0
# 265353                  Vocational training  86000000.0
# 118804  Laboratory and scientific equipment  41000000.0
#
#                                             Segment Title  \
# 111013                    Education and Training Services
# 265353                    Education and Training Services
# 118804  Laboratory and Measuring and Observing and Tes...
#
#                               Location
# 111013                             NaN
# 265353  90007\n(34.027762, -118.28507)
# 118804                             NaN

# %%
test_data_masked.head(3)
# Out:
#        Creation Date Purchase Date Fiscal Year LPA Number  \
# 111013    2014-06-18    2014-05-16   2013-2014        NaN
# 265353    2015-05-01           NaT         NaN        NaN
# 118804           NaT    2014-05-14   2013-2014        NaN
#
#        Purchase Order Number Requisition Number Acquisition Type  \
# 111013               13-5314                NaN  NON-IT Services
# 265353         NMED532237137                NaN  NON-IT Services
# 118804                 X2253                NaN     NON-IT Goods
#
#                                Sub-Acquisition Type  \
# 111013  Services are specifically exempt by statute
# 265353  Services are specifically exempt by statute
# 118804                                          NaN
#
#                                  Acquisition Method Sub-Acquisition Method  \
# 111013                                          NaN                    NaN
# 265353  Services are specifically exempt by statute                    NaN
# 118804                         Informal Competitive                    NaN
#
#                                           Department Name  Supplier Code  \
# 111013  Statewide Health Planning & Development, Offic...      1786916.0
# 265353                      Rehabilitation, Department of      1708000.0
# 118804                             Justice, Department of            NaN
#
#              Supplier Name Supplier Qualifications Supplier Zip Code CalCard  \
# 111013        Paul Mueller                     NaN               NaN      NO
# 265353                 NaN                     NaN             90007      NO
# 118804  Neogen Corporation                     NaN               NaN      NO
#
#                        Item Name  \
# 111013                  Contract
# 265353  vocational rehabiliation
# 118804                       NaN
#
#                                          Item Description  Quantity  \
# 111013                                   Medical Training       1.0
# 265353                                   Summer 2015 fees       1.0
# 118804  methamphetamine Group (RTU) Forensic kit 480 well      18.0
#
#         Unit Price  Total Price Classification Codes  Normalized UNSPSC  \
# 111013      7792.0       7792.0             86101605         86101605.0
# 265353     10935.0      10935.0             86101803         86101803.0
# 118804       335.0       6030.0   41106103\n51151729         41106103.0
#
#                               Commodity Title       Class  \
# 111013   Medical vocational training services  86101600.0
# 265353     Vocational rehabilitation services  86101800.0
# 118804  Deoxyribonucleic acid DNA typing kits  41106100.0
#
#                                          Class Title      Family  \
# 111013       Scientific vocational training services  86100000.0
# 265353  In service training and manpower development  86100000.0
# 118804       Deoxyribonucleic acid DNA analysis kits  41100000.0
#
#                                Family Title     Segment  \
# 111013                  Vocational training  86000000.0
# 265353                  Vocational training  86000000.0
# 118804  Laboratory and scientific equipment  41000000.0
#
#                                             Segment Title  \
# 111013                    Education and Training Services
# 265353                    Education and Training Services
# 118804  Laboratory and Measuring and Observing and Tes...
#
#                               Location
# 111013                             NaN
# 265353  90007\n(34.027762, -118.28507)
# 118804                             NaN

# %%
out_predicted.head(3)
# Out:
#   Creation Date Purchase Date Fiscal Year  LPA Number Purchase Order Number  \
# 0    2011-11-03    2012-03-17   2014-2015  7-11-51-02            4500217746
# 1    2011-10-09    2012-02-21   2014-2015  7-11-51-02              15-10024
# 2    2011-07-27    2011-12-08   2014-2015  1-09-70-02           1PA2L044/45
#
#   Requisition Number Acquisition Type Sub-Acquisition Type  \
# 0                NaN     NON-IT Goods                  NaN
# 1                NaN     NON-IT Goods                  NaN
# 2                NaN     NON-IT Goods                  NaN
#
#      Acquisition Method Sub-Acquisition Method  \
# 0  State Price Schedule                Surplus
# 1  State Price Schedule                Surplus
# 2  State Price Schedule                Surplus
#
#                   Department Name  Supplier Code          Supplier Name  \
# 0  Water Resources, Department of   25675.642719  Unident/Unimed, (USA)
# 1  Water Resources, Department of   25690.317118  Unident/Unimed, (USA)
# 2  Water Resources, Department of   25739.925255   Bay Medical Co., Inc
#
#   Supplier Qualifications Supplier Zip Code CalCard  \
# 0              CA-SBE DBE             75204      NO
# 1              CA-SBE DBE             75204      NO
# 2              CA-SBE DBE             75204      NO
#
#                                  Item Name  \
# 0  GSO Acct 55337 (Mental Health) Blnkt PO
# 1                LabelWriter Turbo Printer
# 2                         OSP Job # 127554
#
#                                     Item Description   Quantity  \
# 0  The Contractor will develop and provide variou...  54.552782
# 1                                        transmitter  53.827356
# 2          Ink Cartridge, HP 88XL, Black, High Yield  52.959586
#
#       Unit Price   Total Price Classification Codes  Normalized UNSPSC  \
# 0  182396.920855  21307.180271             85161502       1.686032e+07
# 1  182396.920855  21217.496094             44121505       7.079147e+06
# 2  182396.920855  21132.018493             44101503       7.079147e+06
#
#                                      Commodity Title         Class  \
# 0                                      Mailing seals  1.544033e+07
# 1                  Mens slacks or trousers or shorts  1.544033e+07
# 2  Dipping sauces or condiments or spreads or mar...  1.544033e+07
#
#                             Class Title        Family  \
# 0  Water treatment and supply equipment  1.379297e+07
# 1            Packaged combination meals  1.379315e+07
# 2            Packaged combination meals  1.379294e+07
#
#                       Family Title       Segment  \
# 0  Castings and casting assemblies  5.002450e+07
# 1  Castings and casting assemblies  5.002451e+07
# 2  Castings and casting assemblies  5.002453e+07
#
#                            Segment Title                        Location
# 0  Manufacturing Components and Supplies  75204\n(32.801403, -96.789068)
# 1  Manufacturing Components and Supplies  75204\n(32.801403, -96.789068)
# 2  Manufacturing Components and Supplies  75204\n(32.801403, -96.789068)
